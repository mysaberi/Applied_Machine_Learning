# %%
import sys
print(sys.version)
# Out:
# 3.9.1 (tags/v3.9.1:1e5d33e, Dec  7 2020, 17:08:21) [MSC v.1927 64 bit (AMD64)]

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 10 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
df = pd.DataFrame(np.random.randn(10, 4)) 
print(df)

j=1.23
for i in range(80000000):
  j+=j    

print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3
# 0 -2.657223 -0.228764 -0.470305 -0.409164
# 1 -3.014806 -1.397686 -0.569492 -2.750417
# 2 -0.001182  0.273228 -0.103738 -0.171249
# 3  1.300539  0.216201  0.285053  0.222364
# 4  0.823350  1.270104  0.611863 -0.840722
# 5 -0.626281  2.103182 -0.976261  0.351127
# 6  1.094739  0.041816 -0.256917 -0.139230
# 7  1.049225 -0.816669  1.805423  0.952299
# 8 -0.649307 -0.035031  0.020812  1.002956
# 9 -1.231379  0.231387  0.196365  0.828344
